# %%
from keras_facenet import FaceNet
import cv2

# %%
embedder = FaceNet()

# %%
image = cv2.imread("/home/andy/Desktop/zoom/insan.jpeg")

# %%
detection = embedder.extract(image,threshold=0.95)

# %%
x,y,w,h= detection[0]['box'][0],detection[0]['box'][1],detection[0]['box'][2], detection[0]['box'][3]

# %%
def _draw(frame, bounding_box_coordinates):
    try:
        persons = 1
        for x, y, w, h in bounding_box_coordinates:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
            cv2.putText(frame, f'person {persons}', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
            persons += 1
        cv2.putText(frame, 'Status : Detecting ', (40, 40), cv2.FONT_HERSHEY_DUPLEX, 0.8, (255, 0, 0), 2)
        cv2.putText(frame, f'Total Persons : {persons - 1}', (40, 70), cv2.FONT_HERSHEY_DUPLEX, 0.8, (255, 0, 0), 2)
        cv2.imshow('output', frame)
    except Exception as e:
        pass

# %%
_draw(image,detection[0]['box'])

# %%
x=[[1,2,3],[4,5,6]]

# %%
detection
# Out:
# [{'box': [233, 274, 450, 587],
#   'confidence': 0.9982786178588867,
#   'keypoints': {'left_eye': (369, 517),
#    'right_eye': (572, 509),
#    'nose': (470, 648),
#    'mouth_left': (372, 715),
#    'mouth_right': (577, 712)},
#   'embedding': array([ 4.43855766e-03,  6.80015609e-02,  3.27375010e-02, -6.46194071e-02,
#          -2.68808808e-02,  2.35235272e-03,  2.85450760e-02,  4.32769163e-03,
#          -1.75292622e-02,  9.99477878e-03, -2.95372400e-02, -4.12865095e-02,
#          -6.52177841e-04,  6.64618686e-02,  4.19622771e-02, -5.48822246e-02,
#          -6.14291541e-02, -2.40849657e-03,  1.85474567e-02, -1.80332211e-03,
#          -5.68886958e-02,  9.68696922e-02,  8.60997662e-02, -4.57957834e-02,
#           3.19520682e-02, -2.19365582e-02, -2.07746960e-02, -9.53838900e-02,
#           1.53963419e-03, -6.88040704e-02, -1.45587642e-02,  5.00533693e-02,
#           5.62177319e-03,  6.59190416e-02,  8.02994967e-02,  2.16391962e-02,
# ...
